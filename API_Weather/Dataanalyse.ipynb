# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from missingno) (2.1.1)
# Requirement already satisfied: matplotlib in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from missingno) (1.14.1)
# Collecting seaborn (from missingno)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\eriks\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn, missingno
# Successfully installed missingno-0.5.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno



df = pd.read_csv("filtered_data_Saturday.csv")

#Beregne gjennomsnittsverdier for variablene med numpy
mean_temp = np.mean(df['Temperatur (°C)'])
mean_wind = np.mean(df['Vindhastighet (km/t)'])
mean_pressure = np.mean(df['Trykk'])
mean_precipitation = np.mean(df['Nedbør (mm)'])

#Beregne medianverdier for variablene med numpy
median_temp = np.median(df['Temperatur (°C)'])
median_wind = np.median(df['Vindhastighet (km/t)'])
median_pressure = np.median(df['Trykk'])
median_precipitation = np.median(df['Nedbør (mm)'])



#Beregne 


#Vindhastighet (km/t)
#Trykk
#Nedbør (mm)

# %%
df = pd.read_csv("trondheim_vaerdata_full_1.csv")

#print(df.dtypes)

df['Tidspunkt'] = pd.to_datetime(df['Tidspunkt'])
df['weekday'] = df['Tidspunkt'].dt.strftime('%A')
df['hour'] = df['Tidspunkt'].dt.hour
 
filtered_df = df[(df['weekday'].isin(['Saturday'])) & (df['hour'] == 10)]

filtered_df.to_csv("filtered_data_Saturday_10.csv", index = False)
print(filtered_df.head(10))
# Out:
#                Tidspunkt  Temperatur (°C)  Vindhastighet (km/t)   Trykk  \
# 58   2025-01-18 10:00:00              2.3                   6.8  1020.0
# 226  2025-01-25 10:00:00              4.1                  19.8   975.0
# 394  2025-02-01 10:00:00             -5.4                   5.8  1030.0
# 562  2025-02-08 10:00:00             -8.3                   9.0  1040.0
# 730  2025-02-15 10:00:00             -9.5                   5.0  1034.0
# 898  2025-02-22 10:00:00              0.0                   5.4  1006.0
# 1066 2025-03-01 10:00:00              0.0                   6.8  1018.0
# 1234 2025-03-08 10:00:00              3.1                   8.6  1018.0
# 1402 2025-03-15 10:00:00              3.2                  34.2  1008.0
#
#       Nedbør (mm)   weekday  hour
# 58           0.13  Saturday    10
# 226          0.00  Saturday    10
# 394          0.00  Saturday    10
# 562          0.00  Saturday    10
# 730          0.00  Saturday    10
# 898          0.00  Saturday    10
# 1066         0.00  Saturday    10
# 1234         0.01  Saturday    10
# 1402         0.02  Saturday    10

# %%
#Lager plots

#Plot for temperatur
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Tidspunkt'], filtered_df['Temperatur (°C)'], color='blue', marker="o", linestyle="-", label="Temperatur")

#Plot for vindhastighet
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Tidspunkt'], filtered_df['Vindhastighet (km/t)'], color='red', marker="o", linestyle="-", label="Temperatur")

#Plot for trykk
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Tidspunkt'], filtered_df['Trykk'], color='green', marker="o", linestyle="-", label="Temperatur")

#Plot for nedbør
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Tidspunkt'], filtered_df['Nedbør (mm)'], color='orange', marker="o", linestyle="-", label="Temperatur")

# %%
#Lag Readme filer 
#Lag source filer
#Lag test filer
#Sjekk opp branches
